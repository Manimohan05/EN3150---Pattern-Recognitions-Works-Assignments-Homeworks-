# %%
import tensorflow as tf

# Check if TensorFlow is using cuDNN
if tf.test.is_built_with_cuda() and tf.test.is_built_with_cudnn():
    print("cuDNN is successfully installed and TensorFlow is using it.")
else:
    print("cuDNN may not be properly installed or configured with TensorFlow.")
# Out:
# cuDNN may not be properly installed or configured with TensorFlow.

# %%
import tensorflow as tf
import numpy as np

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(100, 2)
y = (X[:, 0] + X[:, 1] > 1).astype(int)

# Define a Sequential model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=100, verbose=2)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# Make predictions
predictions = model.predict(X)
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 0.6932 - accuracy: 0.4800 - 570ms/epoch - 142ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 0.6931 - accuracy: 0.5600 - 16ms/epoch - 4ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 0.6931 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 4/100
# 4/4 - 0s - loss: 0.6930 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 0.6930 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 6/100
# 4/4 - 0s - loss: 0.6930 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 7/100
# 4/4 - 0s - loss: 0.6930 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 8/100
# 4/4 - 0s - loss: 0.6930 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 9/100
# 4/4 - 0s - loss: 0.6930 - accuracy: 0.5200 - 5ms/epoch - 1ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 0.6929 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 11/100
# 4/4 - 0s - loss: 0.6929 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 12/100
# 4/4 - 0s - loss: 0.6929 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.6929 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.6929 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.6928 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.6927 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 73/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 75/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 77/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 79/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 80/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 82/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 84/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 85/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 87/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 89/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 90/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 91/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 92/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 94/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 95/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 96/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 12ms/epoch - 3ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 5ms/epoch - 1ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 0.6926 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 99/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 0s/epoch - 0s/step
# Epoch 100/100
# 4/4 - 0s - loss: 0.6925 - accuracy: 0.5200 - 16ms/epoch - 4ms/step
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5200
# Loss: 0.6924691200256348, Accuracy: 0.5199999809265137
# 4/4 [==============================] - 0s 0s/step

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(100, 2)
y = (X[:, 0] + X[:, 1] > 1).astype(int)

# Define a Sequential model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X, y, epochs=100, verbose=0)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# Make predictions
predictions = model.predict(X)

# Plot the decision boundary
x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

plt.contourf(xx, yy, Z, levels=[0, 0.5, 1], cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu, edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Boundary')
plt.show()

# Plot the training history
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['accuracy'], label='Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.title('Training History')
plt.show()
# Out:
# 4/4 [==============================] - 0s 0s/step - loss: 0.6664 - accuracy: 0.5300
# Loss: 0.6663910150527954, Accuracy: 0.5299999713897705
# 4/4 [==============================] - 0s 0s/step
# 313/313 [==============================] - 0s 801us/step

# %%
print(tf.__version__)
# Out:
# 2.13.0

# %%
import tensorflow as tf
if tf.test.is_gpu_available():
    print("TensorFlow is using the GPU.")
else:
    print("TensorFlow is not using the GPU.")
# Out:
# WARNING:tensorflow:From C:\Users\MSI\AppData\Local\Temp\ipykernel_14744\3281647449.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# TensorFlow is not using the GPU.

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print("TensorFlow is using the GPU.")
else:
    print("TensorFlow is not using the GPU.")
# Out:
# TensorFlow is not using the GPU.

# %%
import torch
print(torch.__version__)
# Out:
# 2.1.0+cpu
